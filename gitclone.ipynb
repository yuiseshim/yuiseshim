# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/home/hiroyuki_seshime/.pyenv/versions/3.6.6/envs/tfgpu/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
def gitclone(giturl):
    import git
    import re
    import os
    #dirname = giturl.split('/')[-2]
    dirname = os.path.join(os.getenv('HOME'), 'GitHub', giturl.split('/')[-2])
    gitname = giturl.split('/')[-1]
    pattern = re.compile('.git$')
    gitname = pattern.sub('', gitname)
    gitname = os.path.join(dirname, gitname)
    
    if not os.path.exists(gitname):
        git.Git().clone(giturl, gitname)
        print('Clone '+ gitname)

        #readme = 'README.md'
        #readme = os.path.join(gitname, readme)
        #if not os.path.exists(readme):
        #    with open(readme, 'w') as f:
        #        f.write('')
        #with open(readme, 'r') as f:
        #    lines = f.readlines()
        #url = '##### [url: '+gitname+']('+giturl+')\n'
        #lines.insert(0, url)
        #lines.insert(1, '---------------\n\n')
        #with open(readme, 'w') as f:
        #    f.writelines(lines)
        #print('Add url to README.md')
    else:
        print(gitname + ' exits')

gitstr = """
    https://github.com/BoyuanJiang/Age-Gender-Estimate-TF.git
    https://github.com/GilLevi/AgeGenderDeepLearning.git
    https://github.com/PAIR-code/saliency.git
    https://github.com/PacktPublishing/Building-Machine-Learning-Projects-with-TensorFlow.git
    https://github.com/PacktPublishing/Getting-Started-with-TensorFlow.git
    https://github.com/PacktPublishing/Hands-on-Artificial-Intelligence-with-TensorFlow.git
    https://github.com/PacktPublishing/Machine-learning-with-Sci-kit-Learn-and-Tensorflow-V-.git
    https://github.com/PacktPublishing/Mastering-TensorFlow-1x.git
    https://github.com/PacktPublishing/Mastering-Unsupervised-learning-with-Python.git
    https://github.com/PacktPublishing/Python-Machine-Learning.git
    https://github.com/PacktPublishing/Reinforcement-Learning-with-TensorFlow.git
    https://github.com/PacktPublishing/TensorFlow-1.X-Recipes-for-Supervised-and-Unsupervised-Learning.git
    https://github.com/PacktPublishing/TensorFlow-Deep-Learning-Projects.git
    https://github.com/PacktPublishing/TensorFlow-for-Neural-Network-Solutions.git
    https://github.com/akicho8/SKK-JISYO.shogi.git
    https://github.com/akshath123/Capsule_Generative_Adversarial_Network.git
    https://github.com/algolab-inc/tf-dqn-simple.git
    https://github.com/ageron/handson-ml.git
    https://github.com/arunmandal53/facematch.git
    https://github.com/awjuliani/TF-Tutorials.git
    https://github.com/aymericdamien/TensorFlow-Examples.git
    https://github.com/backstopmedia/tensorflowbook.git
    https://github.com/bjedwards/NetworkXTutorial.git
    https://github.com/bslatkin/effectivepython.git
    https://github.com/cellist/Lilypond-Sheet-Music.git
    https://github.com/ck2886/TransferLearning_Tensoflow.git
    https://github.com/cocodataset/cocoapi.git
    https://github.com/davidsandberg/facenet.git
    https://github.com/deepblacksky/capsnet-tensorflow.git
    https://github.com/deepmind/dsprites-dataset.git
    https://github.com/deepmind/gqn-datasets.git
    https://github.com/deepmind/slim-dataset.git
    https://github.com/dennybritz/reinforcement-learning.git
    https://github.com/dontfollowmeimcrazy/imagenet.git
    https://github.com/dpressel/rude-carnie.git
    https://github.com/elsehow/google-image-search-scraper.git
    https://github.com/eltonlaw/vgg-cifar10
    https://github.com/elyas74/nlp-gender-recognition
    https://github.com/enakai00/jupyter_tfbook.git
    https://github.com/getrasa/GoogLeNet-Implementation.git
    https://github.com/gliese581gg/YOLO_tensorflow.git
    https://github.com/google/dopamine.git
    https://github.com/gyang274/capsulesEM.git
    https://github.com/hellochick/ICNet-tensorflow.git
    https://github.com/horndude77/open-scores.git
    https://github.com/insikk/Grad-CAM-tensorflow.git
    https://github.com/jerryfan4/ResNet.git
    https://github.com/junpenglao/GLMM-in-Python.git
    https://github.com/kratzert/finetune_alexnet_with_tensorflow.git
    https://github.com/luispedro/BuildingMachineLearningSystemsWithPython.git
    https://github.com/martinbjeldbak/ultimate-beamer-theme-list.git
    https://github.com/matterport/Mask_RCNN.git
    https://github.com/nanfengpo/age-gender-estimation.git
    https://github.com/naturomics/CapsNet-Tensorflow.git
    https://github.com/nfmcclure/tensorflow_cookbook.git
    https://github.com/oarriaga/face_classification.git
    https://github.com/openimages/dataset.git
    https://github.com/oreilly-japan/automatestuff-ja.git
    https://github.com/oreilly-japan/black-hat-python-jp-support.git
    https://github.com/oreilly-japan/deep-learning-from-scratch-2.git
    https://github.com/oreilly-japan/deep-learning-from-scratch.git
    https://github.com/oreilly-japan/fundamentals-of-deep-learning-ja.git
    https://github.com/quantumlib/Cirq.git
    https://github.com/quantumlib/OpenFermion.git
    https://github.com/quantumlib/OpenFermion-Cirq.git
    https://github.com/quantumlib/OpenFermion-Psi4.git
    https://github.com/rasbt/python-machine-learning-book-2nd-edition.git
    https://github.com/rasbt/python-machine-learning-book.git
    https://github.com/ritchieng/resnet-tensorflow.git
    https://github.com/ry/tensorflow-resnet.git
    https://github.com/scoliann/GenderClassifierCNN.git
    https://github.com/simoninithomas/Deep_reinforcement_learning_Course.git
    https://github.com/tensorflow/hub.git
    https://github.com/tensorflow/models.git
    https://github.com/tensorflow/nmt.git
    https://github.com/tensorflow/probability.git
    https://github.com/tensorflow/serving.git
    https://github.com/tensorflow/tensorboard.git
    https://github.com/tensorflow/tensorflow.git
    https://github.com/tensorflow/workshops.git
    https://github.com/tensorlayer/dcgan.git
    https://github.com/tepreece/bach-cello-suites.git
    https://github.com/tetrachrome/subpixel.git
    https://github.com/tracylau/burlesque.git
    https://github.com/truongnmt/multi-task-learning.git
    https://github.com/truongnmt/smile-detection.git
    https://github.com/tzutalin/labelImg.git
    https://github.com/udacity/deep-learning.git
    https://github.com/volvet/RAISR-1.git
    https://github.com/wenxinxu/resnet-in-tensorflow.git
    https://github.com/xuyuwei/resnet-tf.git
    https://github.com/yamika/jikyu600_box.git
"""


import re
pattern = re.compile('\s+')
gitlist = re.split(pattern, gitstr)
gitlist = list(filter(lambda x:x!='', gitlist))

#########
gitlist.sort()
for i in gitlist:
    print(i)
#########

list(map(gitclone, gitlist))
# Out:
# https://github.com/BoyuanJiang/Age-Gender-Estimate-TF.git
# https://github.com/GilLevi/AgeGenderDeepLearning.git
# https://github.com/PAIR-code/saliency.git
# https://github.com/PacktPublishing/Building-Machine-Learning-Projects-with-TensorFlow.git
# https://github.com/PacktPublishing/Getting-Started-with-TensorFlow.git
# https://github.com/PacktPublishing/Hands-on-Artificial-Intelligence-with-TensorFlow.git
# https://github.com/PacktPublishing/Machine-learning-with-Sci-kit-Learn-and-Tensorflow-V-.git
# https://github.com/PacktPublishing/Mastering-TensorFlow-1x.git
# https://github.com/PacktPublishing/Mastering-Unsupervised-learning-with-Python.git
# https://github.com/PacktPublishing/Python-Machine-Learning.git
# https://github.com/PacktPublishing/Reinforcement-Learning-with-TensorFlow.git
# https://github.com/PacktPublishing/TensorFlow-1.X-Recipes-for-Supervised-and-Unsupervised-Learning.git
# https://github.com/PacktPublishing/TensorFlow-Deep-Learning-Projects.git
# ...
